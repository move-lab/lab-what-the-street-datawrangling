# %%
# %matplotlib inline

# %% [markdown]
# # Determine street unwind order
#
# Created on:  2016-11-15
# Last update: 2016-11-16
# Contact: michael.szell@moovel.com, michael.szell@gmail.com (Michael Szell)

# %%
# preliminaries
from __future__ import unicode_literals
import sys
import csv
import os
import math
import pprint
import requests
import gzip
from collections import defaultdict
import time
import datetime
import numpy as np
from scipy import stats
import pyprind
import itertools
import logging
from ast import literal_eval as make_tuple
from collections import OrderedDict
from retrying import retry

import osmnx as ox
import networkx as nx
import json
from shapely.geometry import mapping, shape, LineString, LinearRing, Polygon, MultiPolygon
import shapely
import shapely.ops as ops
from functools import partial
import pyproj
from scipy import spatial
from haversine import haversine

import pymongo
from pymongo import MongoClient

# plotting stuff
import matplotlib.pyplot as plt

pathdatain = '/Users/szellmi/Documents/lab-mobviz/_playground/berlin-street-wurst/'
pathdataout = '/Users/szellmi/Documents/lab-mobviz/_playground/berlin-street-wurst/'
pp = pprint.PrettyPrinter(indent=4)

# City parameters (generalize later)
cityname = "berlin"
bbox = "52.33812, 13.0884, 52.675499, 13.76134" 
# berlin: 52.33812, 13.0884, 52.675499, 13.76134
# newyork: 40.496044, -74.255735, 40.915256, -73.700272
# stuttgart: 48.46, 8.79, 48.93, 9.50
# amsterdam: 52.3216, 4.7685, 52.4251, 5.0173
with open(pathdatain + cityname +"_streetnames.txt", "r") as ins:
    streetnames = []
    for line in ins:
        streetnames.append(line.rstrip('\n'))

# %%
client = MongoClient()
db = client[cityname+'_raw']
ways = db['ways']
nodes = db['nodes']
db_derived = client[cityname+'_derived']
streets = db_derived['streets']

# %%
def file_len(fname): # http://stackoverflow.com/questions/845058/how-to-get-line-count-cheaply-in-python
    with open(fname) as f:
        for i, l in enumerate(f):
            pass
    return i + 1

def assembleStreet(ways, streetname = "Achillesstraße", drawit = False):
    oxelements = []
    elemnodesint = set()
    elemways = []
    elemnodes = []
    nodesdict = {}
    for i,way in enumerate(ways.find({"tags.name":streetname})):
        for n in way["loc"]["nodes"]:
            elemnodesint.add(int(n))
        elemways.append({"id": int(way["_id"]), "nodes":[int(way["loc"]["nodes"][k]) for k in range(len(way["loc"]["nodes"]))], "tags": way["tags"], "type": "way"})

    for n in elemnodesint:
        for nd in nodes.find({"_id": n}):
            elemnodes.append({"id": int(nd["_id"]), "lat": nd["loc"]["coordinates"][1], "lon": nd["loc"]["coordinates"][0], "type": "node"})
            nodesdict[str(int(nd["_id"]))] = {"lat": nd["loc"]["coordinates"][1], "lon": nd["loc"]["coordinates"][0]}

    oxelements = [{"elements": elemnodes + elemways}]

    G = ox.create_graph(oxelements, retain_all=True)
    if drawit:
        fig, ax = ox.plot_graph(G)
    G = nx.Graph(G)
    G = G.to_undirected()
    ccs = list(nx.connected_component_subgraphs(G))

    components = []
    for c in range(len(ccs)):
        deglist = np.array(list((ccs[c].degree_iter())))
        endptindices = np.where(deglist[:, 1] == 1)
        # Look which of the endpoints lies most western, take that as the source for DFS traversal
        west = float('inf')
        source = deglist[0, 0]
        for i in list(endptindices[0]):
            westthis = nodesdict[str(deglist[i, 0])]["lon"]
            if westthis < west:
                source = deglist[i, 0]
                west = westthis

        component = []
        dfsedges = list(nx.dfs_edges(ccs[c], source))
        nend = dfsedges[0][0]
        path = [str(nend)]
        for e in dfsedges:
            if e[0] == nend: # path grows
                path.append(str(e[1]))
            else: # new path
                component.append(path)
                path = [str(e[0]), str(e[1])]
            nend = e[1]    
        component.append(path) # last path
        components.append(component)
        
    output = {"tags":{"name":streetname}, "components":components, "nodes":nodesdict}
    return output

# %%
# test case. To get its output, insert this in the above function after oxelements = ...
oxelements = [{"elements": [{   'id': 1,
                            'lat': 0,
                            'lon': -1,
                            'type': 'node'},
                            {   'id': 2,
                            'lat': 0,
                            'lon': 1,
                            'type': 'node'},
                            {   'id': 3,
                            'lat': -1,
                            'lon': 1,
                            'type': 'node'},
                            {   'id': 4,
                            'lat': -2,
                            'lon': 1,
                            'type': 'node'},
                            {   'id': 5,
                            'lat': 0,
                            'lon': 2,
                            'type': 'node'},
                            {   'id': 6,
                            'lat': -1,
                            'lon': 0,
                            'type': 'node'},
                            {   'id': 7,
                            'lat': 0,
                            'lon': 3,
                            'type': 'node'},
                            {   'id': 8,
                            'lat': -1,
                            'lon': 4,
                            'type': 'node'},
                            {   'id': 91,
                            'nodes': [1, 2, 3],
                            'type': 'way'},
                            {   'id': 92,
                            'nodes': [2, 5],
                            'type': 'way'},
                            {   'id': 93,
                            'nodes': [3, 4],
                            'type': 'way'},
                            {   'id': 94,
                            'nodes': [6, 3],
                            'type': 'way'},
                            {   'id': 95,
                            'nodes': [7, 8],
                            'type': 'way'}
                           ]}]    
nodesdict = {"1":{'lat': 0, 'lon': -1}, 
            "2":{'lat': 0, 'lon': 1}, 
            "3":{'lat': -1, 'lon': 1}, 
            "4":{'lat': -2, 'lon': 1}, 
            "5":{'lat': 0, 'lon': 2}, 
            "6":{'lat': -1, 'lon': 0}, 
            "7":{'lat': 0, 'lon': 3}, 
            "8":{'lat': -1, 'lon': 4}
            }

# %%
streets.drop()  
bar = pyprind.ProgBar(len(streetnames), bar_char='█', update_interval=1)
for i,streetname in enumerate(streetnames):
    try:
        res = assembleStreet(ways, streetname)
        res["_id"] = i+1
        streets.insert_one(res)
    except:
        print(streetname + " could not be inserted.")
    bar.update(item_id = streetname)
# Out:
# 0%                          100%
# [                              ]
# [   {   'elements': [   {   'id': 26729494,
#                             'lat': 52.4797549,
#                             'lon': 13.3155064,
#                             'type': 'node'},
#                         {   'id': 26729495,
#                             'lat': 52.4796107,
#                             'lon': 13.3155776,
#                             'type': 'node'},
#                         {   'id': 26729496,
#                             'lat': 52.4795039,
#                             'lon': 13.3157925,
#                             'type': 'node'},
#                         {   'id': 26729497,
#                             'lat': 52.4794189,
#                             'lon': 13.3160304,
#                             'type': 'node'},
#                         {   'id': 935608857,
#                             'lat': 52.4825102,
#                             'lon': 13.3184282,
#                             'type': 'node'},
#                         {   'id': 26729498,
#                             'lat': 52.4793657,
#                             'lon': 13.3162063,
#                             'type': 'node'},
#                         {   'id': 26729499,
#                             'lat': 52.4791523,
#                             'lon': 13.3169015,
#                             'type': 'node'},
#                         {   'id': 26729500,
#                             'lat': 52.4789683,
#                             'lon': 13.3179174,
#                             'type': 'node'},
#                         {   'id': 353681182,
#                             'lat': 52.478948,
#                             'lon': 13.3181786,
#                             'type': 'node'},
#                         {   'id': 353681183,
#                             'lat': 52.4790005,
#                             'lon': 13.3186552,
#                             'type': 'node'},
#                         {   'id': 26729504,
#                             'lat': 52.4791148,
#                             'lon': 13.318813,
#                             'type': 'node'},
#                         {   'id': 26729505,
#                             'lat': 52.4792106,
#                             'lon': 13.3188581,
#                             'type': 'node'},
#                         {   'id': 26729506,
#                             'lat': 52.4814412,
#                             'lon': 13.3189402,
#                             'type': 'node'},
#                         {   'id': 353681184,
#                             'lat': 52.4790941,
#                             'lon': 13.3171599,
#                             'type': 'node'},
#                         {   'id': 353681185,
#                             'lat': 52.4792395,
#                             'lon': 13.3166164,
#                             'type': 'node'},
#                         {   'id': 353681186,
#                             'lat': 52.4795537,
#                             'lon': 13.3156732,
#                             'type': 'node'},
#                         {   'id': 26729502,
#                             'lat': 52.4789371,
#                             'lon': 13.3183653,
#                             'type': 'node'},
#                         {   'id': 26729503,
#                             'lat': 52.4790512,
#                             'lon': 13.3187452,
#                             'type': 'node'},
#                         {   'id': 26729518,
#                             'lat': 52.4815623,
#                             'lon': 13.3188809,
#                             'type': 'node'},
#                         {   'id': 26729520,
#                             'lat': 52.4827928,
#                             'lon': 13.3182849,
#                             'type': 'node'},
#                         {   'id': 779195853,
#                             'lat': 52.479025,
#                             'lon': 13.3174793,
#                             'type': 'node'},
#                         {   'id': 270677078,
#                             'lat': 52.4789583,
#                             'lon': 13.3185456,
#                             'type': 'node'},
#                         {   'id': 1324598103,
#                             'lat': 52.4793006,
#                             'lon': 13.318873,
#                             'type': 'node'},
#                         {   'id': 2030492139,
#                             'lat': 52.4796929,
#                             'lon': 13.315534,
#                             'type': 'node'},
#                         {   'id': 4442071,
#                             'nodes': [   26729520,
#                                          935608857,
#                                          26729518,
#                                          26729506,
#                                          1324598103,
#                                          26729505,
#                                          26729504,
#                                          26729503,
#                                          353681183,
#                                          270677078,
#                                          26729502],
#                             'tags': {   'highway': 'residential',
#                                         'lit': 'yes',
#                                         'maxspeed': '30',
#                                         'name': 'Aachener Straße',
#                                         'postal_code': '10713',
#                                         'surface': 'cobblestone'},
#                             'type': 'way'},
#                         {   'id': 85129361,
#                             'nodes': [   26729502,
#                                          353681182,
#                                          26729500,
#                                          779195853,
#                                          353681184,
#                                          26729499,
#                                          353681185,
#                                          26729498,
#                                          26729497,
#                                          26729496,
#                                          353681186,
#                                          26729495],
#                             'tags': {   'cycleway': 'track',
#                                         'footway': 'right',
#                                         'highway': 'residential',
#                                         'lit': 'yes',
#                                         'maxspeed': '30',
#                                         'name': 'Aachener Straße',
#                                         'postal_code': '10713'},
#                             'type': 'way'},
#                         {   'id': 85129381,
#                             'nodes': [26729495, 2030492139, 26729494],
#                             'tags': {   'highway': 'residential',
#                                         'lit': 'yes',
#                                         'maxspeed': '30',
#                                         'name': 'Aachener Straße',
#                                         'postal_code': '10713'},
#                             'type': 'way'}]}]
# [   {   'elements': [   {   'id': 1379337606,
#                             'lat': 52.5731002,
#                             'lon': 13.2191134,
#                             'type': 'node'},
#                         {   'id': 1379337610,
#                             'lat': 52.5731166,
#                             'lon': 13.2186061,
#                             'type': 'node'},
#                         {   'id': 1379337611,
#                             'lat': 52.5730683,
#                             'lon': 13.2201431,
#                             'type': 'node'},
#                         {   'id': 1379337612,
#                             'lat': 52.5730841,
#                             'lon': 13.2196335,
#                             'type': 'node'},
#                         {   'id': 506480662,
#                             'lat': 52.5732961,
#                             'lon': 13.2129473,
#                             'type': 'node'},
#                         {   'id': 3990705177,
#                             'lat': 52.5727959,
#                             'lon': 13.2128936,
#                             'type': 'node'},
#                         {   'id': 3990705179,
#                             'lat': 52.5729008,
#                             'lon': 13.2128469,
#                             'type': 'node'},
#                         {   'id': 3990705181,
#                             'lat': 52.5730987,
#                             'lon': 13.2129864,
#                             'type': 'node'},
#                         {   'id': 3990705185,
#                             'lat': 52.5733319,
#                             'lon': 13.2124769,
#                             'type': 'node'},
#                         {   'id': 3990705186,
#                             'lat': 52.5734435,
#                             'lon': 13.2124382,
#                             'type': 'node'},
#                         {   'id': 3990705187,
#                             'lat': 52.5734876,
#                             'lon': 13.212526,
#                             'type': 'node'},
#                         {   'id': 451695663,
#                             'lat': 52.5732175,
#                             'lon': 13.2129271,
#                             'type': 'node'},
#                         {   'id': 2224771504,
#                             'lat': 52.5729699,
#                             'lon': 13.2226048,
#                             'type': 'node'},
#                         {   'id': 248569009,
#                             'lat': 52.5729824,
#                             'lon': 13.2221537,
#                             'type': 'node'},
#                         {   'id': 451695664,
#                             'lat': 52.5734025,
#                             'lon': 13.2124521,
#                             'type': 'node'},
#                         {   'id': 247382580,
#                             'lat': 52.5733028,
#                             'lon': 13.212554,
#                             'type': 'node'},
#                         {   'id': 506480309,
#                             'lat': 52.5735822,
#                             'lon': 13.2124971,
#                             'type': 'node'},
#                         {   'id': 247382583,
#                             'lat': 52.5731071,
#                             'lon': 13.2188921,
#                             'type': 'node'},
#                         {   'id': 247382584,
#                             'lat': 52.5730265,
#                             'lon': 13.2211918,
#                             'type': 'node'},
#                         {   'id': 247382840,
#                             'lat': 52.5732104,
#                             'lon': 13.2158753,
#                             'type': 'node'},
#                         {   'id': 247382586,
#                             'lat': 52.5729622,
#                             'lon': 13.2228824,
#                             'type': 'node'},
#                         {   'id': 248540090,
#                             'lat': 52.5731755,
#                             'lon': 13.2169269,
#                             'type': 'node'},
#                         {   'id': 1385215683,
#                             'lat': 52.5729856,
#                             'lon': 13.2237058,
#                             'type': 'node'},
#                         {   'id': 2224769733,
#                             'lat': 52.5730888,
#                             'lon': 13.2229416,
#                             'type': 'node'},
#                         {   'id': 551219798,
#                             'lat': 52.5730037,
#                             'lon': 13.2216601,
#                             'type': 'node'},
#                         {   'id': 248539992,
#                             'lat': 52.5732776,
#                             'lon': 13.213705,
#                             'type': 'node'},
#                         {   'id': 248540123,
#                             'lat': 52.5732913,
#                             'lon': 13.2131672,
#                             'type': 'node'},
#                         {   'id': 248540541,
#                             'lat': 52.5731426,
#                             'lon': 13.2178194,
#                             'type': 'node'},
#                         {   'id': 248540000,
#                             'lat': 52.5732464,
#                             'lon': 13.2147843,
#                             'type': 'node'},
#                         {   'id': 747990890,
#                             'lat': 52.5730499,
#                             'lon': 13.2238859,
#                             'type': 'node'},
#                         {   'id': 251543421,
#                             'lat': 52.5730526,
#                             'lon': 13.2206475,
#                             'type': 'node'},
#                         {   'id': 22959737,
#                             'nodes': [   247382580,
#                                          506480662,
#                                          248540123,
#                                          248539992,
#                                          248540000,
#                                          247382840,
#                                          248540090,
#                                          248540541,
#                                          1379337610,
#                                          247382583,
#                                          1379337606,
#                                          1379337612,
#                                          1379337611,
#                                          251543421,
#                                          247382584,
#                                          551219798],
#                             'tags': {   'highway': 'tertiary',
#                                         'name': 'Aalemannufer',
#                                         'note': 'Ergänzungsstraße mit '
#                                                 'besonderer Bedeutung',
#                                         'postal_code': '13587'},
#                             'type': 'way'},
#                         {   'id': 23722412,
#                             'nodes': [   248569009,
#                                          2224771504,
#                                          247382586,
#                                          1385215683,
#                                          747990890],
#                             'tags': {   'highway': 'tertiary',
#                                         'name': 'Aalemannufer',
#                                         'postal_code': '13587'},
#                             'type': 'way'},
#                         {   'id': 48273148,
#                             'nodes': [551219798, 248569009],
#                             'tags': {   'highway': 'tertiary',
#                                         'name': 'Aalemannufer',
#                                         'note': 'Ergänzungsstraße mit '
#                                                 'besonderer Bedeutung',
#                                         'postal_code': '13587'},
#                             'type': 'way'},
#                         {   'id': 212647327,
#                             'nodes': [2224771504, 2224769733],
#                             'tags': {   'highway': 'service',
#                                         'name': 'Aalemannufer'},
#                             'type': 'way'},
#                         {   'id': 396267044,
#                             'nodes': [451695663, 3990705181],
#                             'tags': {   'bench': 'yes',
#                                         'bin': 'yes',
#                                         'bus': 'yes',
#                                         'name': 'Aalemannufer',
#                                         'passenger_information_display': 'no',
#                                         'public_transport': 'platform',
#                                         'shelter': 'yes',
#                                         'tactile_paving': 'no'},
#                             'type': 'way'},
#                         {   'id': 396267048,
#                             'nodes': [3990705179, 3990705177],
#                             'tags': {   'bench': 'no',
#                                         'bin': 'no',
#                                         'bus': 'yes',
#                                         'name': 'Aalemannufer',
#                                         'note': 'Endhaltestelle',
#                                         'passenger_information_display': 'no',
#                                         'public_transport': 'platform',
#                                         'shelter': 'no',
#                                         'tactile_paving': 'no'},
#                             'type': 'way'},
#                         {   'id': 396267051,
#                             'nodes': [506480309, 3990705187],
#                             'tags': {   'bench': 'yes',
#                                         'bin': 'yes',
#                                         'bus': 'yes',
#                                         'name': 'Aalemannufer',
#                                         'passenger_information_display': 'no',
#                                         'public_transport': 'platform',
#                                         'shelter': 'yes',
#                                         'tactile_paving': 'no'},
#                             'type': 'way'},
#                         {   'id': 396267054,
#                             'nodes': [3990705185, 451695664, 3990705186],
#                             'tags': {   'bench': 'no',
#                                         'bin': 'no',
#                                         'bus': 'yes',
#                                         'name': 'Aalemannufer',
#                                         'passenger_information_display': 'no',
#                                         'public_transport': 'platform',
#                                         'shelter': 'no',
#                                         'tactile_paving': 'no'},
#                             'type': 'way'}]}]
# [   {   'elements': [   {   'id': 29422100,
#                             'lat': 52.5542835,
#                             'lon': 13.4075127,
#                             'type': 'node'},
#                         {   'id': 29422047,
#                             'lat': 52.555499,
#                             'lon': 13.40769,
#                             'type': 'node'},
#                         {   'id': 8152828,
#                             'nodes': [29422047, 29422100],
#                             'tags': {   'highway': 'residential',
#                                         'maxspeed': '30',
#                                         'name': 'Aalesunder Straße',
#                                         'postal_code': '10439',
#                                         'surface': 'cobblestone'},
#                             'type': 'way'}]}]
# [                              ] | ETA: 00:39:59 | Item ID: Aalstieg
# [   {   'elements': [   {   'id': 1650837026,
#                             'lat': 52.4355347,
#                             'lon': 13.6896926,
#                             'type': 'node'},
#                         {   'id': 251359435,
#                             'lat': 52.435327,
#                             'lon': 13.6908446,
#                             'type': 'node'},
#                         {   'id': 1650837037,
#                             'lat': 52.4356514,
#                             'lon': 13.6892206,
#                             'type': 'node'},
#                         {   'id': 1650837042,
#                             'lat': 52.4359177,
#                             'lon': 13.6885292,
#                             'type': 'node'},
#                         {   'id': 2821295955,
#                             'lat': 52.4353516,
#                             'lon': 13.693157,
#                             'type': 'node'},
#                         {   'id': 251910804,
#                             'lat': 52.4353207,
#                             'lon': 13.6912957,
#                             'type': 'node'},
#                         {   'id': 31495992,
#                             'lat': 52.435744,
#                             'lon': 13.6888982,
#                             'type': 'node'},
#                         {   'id': 4199933882,
#                             'lat': 52.4354235,
#                             'lon': 13.6901445,
#                             'type': 'node'},
#                         {   'id': 1650837020,
#                             'lat': 52.4353387,
#                             'lon': 13.6932643,
#                             'type': 'node'},
#                         {   'id': 2820446781,
#                             'lat': 52.4358135,
#                             'lon': 13.6887228,
#                             'type': 'node'},
#                         {   'id': 31495998,
#                             'lat': 52.4353441,
#                             'lon': 13.6924281,
#                             'type': 'node'},
#                         {   'id': 152258280,
#                             'nodes': [   1650837042,
#                                          2820446781,
#                                          31495992,
#                                          1650837037,
#                                          1650837026,
#                                          4199933882,
#                                          251359435,
#                                          251910804,
#                                          31495998,
#                                          2821295955,
#                                          1650837020],
#                             'tags': {   'highway': 'residential',
#                                         'maxspeed': '30',
#                                         'name': 'Aalstieg',
#                                         'old_name': 'Straße 565',
#                                         'oneway': 'no',
#                                         'postal_code': '12589'},
#                             'type': 'way'}]}]
# [   {   'elements': [   {   'id': 153897649,
#                             'lat': 52.4237506,
#                             'lon': 13.2917694,
#                             'type': 'node'},
#                         {   'id': 31387121,
#                             'lat': 52.4268243,
#                             'lon': 13.2896927,
#                             'type': 'node'},
#                         {   'id': 148325351,
#                             'nodes': [153897649, 31387121],
#                             'tags': {   'highway': 'residential',
#                                         'lit': 'yes',
#                                         'maxspeed': '30',
#                                         'name': 'Aarauer Straße',
#                                         'postal_code': '12205'},
#                             'type': 'way'}]}]
# [   {   'elements': [   {   'id': 3983314340,
#                             'lat': 52.424932,
#                             'lon': 13.3007894,
#                             'type': 'node'},
#                         {   'id': 261702277,
#                             'lat': 52.4257512,
#                             'lon': 13.3008185,
#                             'type': 'node'},
#                         {   'id': 975649348,
#                             'lat': 52.4256423,
#                             'lon': 13.3008404,
#                             'type': 'node'},
#                         {   'id': 664591440,
#                             'lat': 52.4253556,
#                             'lon': 13.3008228,
#                             'type': 'node'},
#                         {   'id': 975649328,
#                             'lat': 52.4256251,
#                             'lon': 13.3016162,
#                             'type': 'node'},
#                         {   'id': 31387102,
#                             'lat': 52.424901,
#                             'lon': 13.3007658,
#                             'type': 'node'},
#                         {   'id': 24160799,
#                             'nodes': [   31387102,
#                                          3983314340,
#                                          664591440,
#                                          975649348,
#                                          261702277],
#                             'tags': {   'highway': 'residential',
#                                         'lit': 'yes',
#                                         'maxspeed': '30',
#                                         'name': 'Aarberger Straße',
#                                         'postal_code': '12205',
#                                         'surface': 'concrete'},
#                             'type': 'way'},
#                         {   'id': 83800303,
#                             'nodes': [975649348, 975649328],
#                             'tags': {   'access': 'private',
#                                         'highway': 'living_street',
#                                         'name': 'Aarberger Straße',
#                                         'postal_code': '12205'},
#                             'type': 'way'}]}]
# [   {   'elements': [   {   'id': 30561428,
#                             'lat': 52.5901324,
#                             'lon': 13.3906109,
#                             'type': 'node'},
#                         {   'id': 30561423,
#                             'lat': 52.5905212,
#                             'lon': 13.3931379,
#                             'type': 'node'},
#                         {   'id': 4777272,
#                             'nodes': [30561428, 30561423],
#                             'tags': {   'created_by': 'Potlatch 0.7',
#                                         'highway': 'residential',
#                                         'maxspeed': '30',
#                                         'name': 'Abajstraße',
#                                         'postal_code': '13158'},
#                             'type': 'way'}]}]
# [                              ] | ETA: 00:39:17 | Item ID: Abbestraße
# [   {   'elements': [   {   'id': 27409696,
#                             'lat': 52.5177507,
#                             'lon': 13.3219613,
#                             'type': 'node'},
#                         {   'id': 3791061893,
#                             'lat': 52.5156204,
#                             'lon': 13.3202146,
#                             'type': 'node'},
#                         {   'id': 3791061894,
#                             'lat': 52.515777,
#                             'lon': 13.3203441,
#                             'type': 'node'},
#                         {   'id': 2617460299,
#                             'lat': 52.5153333,
#                             'lon': 13.3199774,
#                             'type': 'node'},
#                         {   'id': 387420016,
#                             'lat': 52.5165709,
#                             'lon': 13.321006,
#                             'type': 'node'},
#                         {   'id': 27409746,
#                             'lat': 52.5152549,
#                             'lon': 13.319913,
#                             'type': 'node'},
#                         {   'id': 1315120089,
#                             'lat': 52.5163069,
#                             'lon': 13.320782,
#                             'type': 'node'},
#                         {   'id': 27409724,
#                             'lat': 52.5167013,
#                             'lon': 13.3211095,
#                             'type': 'node'},
#                         {   'id': 152832868,
#                             'nodes': [27409696, 27409724],
#                             'tags': {   'highway': 'residential',
#                                         'maxspeed': '30',
#                                         'name': 'Abbestraße',
#                                         'postal_code': '10587'},
#                             'type': 'way'},
#                         {   'id': 152832871,
#                             'nodes': [   27409724,
#                                          387420016,
#                                          1315120089,
#                                          3791061894,
#                                          3791061893,
#                                          2617460299,
#                                          27409746],
#                             'tags': {   'access': 'customers',
#                                         'bicycle': 'no',
#                                         'cycleway': 'opposite',
#                                         'highway': 'residential',
#                                         'horse': 'no',
#                                         'maxspeed': '50',
#                                         'name': 'Abbestraße',
#                                         'oneway': 'yes',
#                                         'postal_code': '10587',
#                                         'vehicle': 'destination'},
#                             'type': 'way'}]}]
# [   {   'elements': [   {   'id': 29739641,
#                             'lat': 52.3924286,
#                             'lon': 13.388229,
#                             'type': 'node'},
#                         {   'id': 1654022818,
#                             'lat': 52.3926283,
#                             'lon': 13.3921795,
#                             'type': 'node'},
#                         {   'id': 29739661,
#                             'lat': 52.3924385,
#                             'lon': 13.3904241,
#                             'type': 'node'},
#                         {   'id': 1654022815,
#                             'lat': 52.3924582,
#                             'lon': 13.3915482,
#                             'type': 'node'},
#                         {   'id': 152593430,
#                             'nodes': [   29739641,
#                                          29739661,
#                                          1654022815,
#                                          1654022818],
#                             'tags': {   'highway': 'residential',
#                                         'lit': 'yes',
#                                         'maxspeed': '30',
#                                         'name': 'Abendrotweg',
#                                         'postal_code': '12307',
#                                         'surface': 'cobblestone'},
#                             'type': 'way'}]}]
# [   {   'elements': [   {   'id': 4004564033,
#                             'lat': 52.4324266,
#                             'lon': 13.5277769,
#                             'type': 'node'},
#                         {   'id': 664166211,
#                             'lat': 52.4331413,
#                             'lon': 13.5290239,
#                             'type': 'node'},
#                         {   'id': 2648427260,
#                             'lat': 52.4339985,
#                             'lon': 13.5304968,
#                             'type': 'node'},
#                         {   'id': 664166202,
#                             'lat': 52.4326045,
#                             'lon': 13.5280942,
#                             'type': 'node'},
#                         {   'id': 38919786,
#                             'lat': 52.4339576,
#                             'lon': 13.5304268,
#                             'type': 'node'},
#                         {   'id': 1077243146,
#                             'lat': 52.4321357,
#                             'lon': 13.5272582,
#                             'type': 'node'},
#                         {   'id': 1077243245,
#                             'lat': 52.4345583,
#                             'lon': 13.5314541,
#                             'type': 'node'},
#                         {   'id': 664166125,
#                             'lat': 52.4320759,
#                             'lon': 13.5271414,
#                             'type': 'node'},
#                         {   'id': 664166127,
#                             'lat': 52.4321022,
#                             'lon': 13.5271914,
#                             'type': 'node'},
#                         {   'id': 833045584,
#                             'lat': 52.4333339,
#                             'lon': 13.5293588,
#                             'type': 'node'},
#                         {   'id': 1912657493,
#                             'lat': 52.4327662,
#                             'lon': 13.5283735,
#                             'type': 'node'},
#                         {   'id': 1560225398,
#                             'lat': 52.4346279,
#                             'lon': 13.5315749,
#                             'type': 'node'},
#                         {   'id': 1077243194,
#                             'lat': 52.433198,
#                             'lon': 13.5291227,
#                             'type': 'node'},
#                         {   'id': 2648427259,
#                             'lat': 52.4339138,
#                             'lon': 13.5303519,
#                             'type': 'node'},
#                         {   'id': 833046588,
#                             'lat': 52.4334953,
#                             'lon': 13.5296362,
#                             'type': 'node'},
#                         {   'id': 1077243198,
#                             'lat': 52.4330856,
#                             'lon': 13.5289254,
#                             'type': 'node'},
#                         {   'id': 142575655,
#                             'nodes': [   1560225398,
#                                          1077243245,
#                                          2648427260,
#                                          38919786,
#                                          2648427259,
#                                          833046588,
#                                          833045584,
#                                          1077243194,
#                                          664166211,
#                                          1077243198,
#                                          1912657493,
#                                          664166202,
#                                          4004564033,
#                                          1077243146,
#                                          664166127,
#                                          664166125],
#                             'tags': {   'highway': 'unclassified',
#                                         'lanes': '2',
#                                         'lit': 'yes',
#                                         'maxspeed': '50',
#                                         'name': 'Abram-Joffe-Straße',
#                                         'postal_code': '12489',
#                                         'sidewalk': {   'smoothness': 'intermediate',
#                                                         'surface': 'paving_stones'},
#                                         'smoothness': 'excellent',
#                                         'surface': 'asphalt',
#                                         'width': '6.5'},
#                             'type': 'way'}]}]
# [   {   'elements': [   {   'id': 259404816,
#                             'lat': 52.4354495,
#                             'lon': 13.5436122,
#                             'type': 'node'},
#                         {   'id': 3867211100,
#                             'lat': 52.4356,
#                             'lon': 13.5432933,
#                             'type': 'node'},
#                         {   'id': 484225813,
#                             'lat': 52.4354925,
#                             'lon': 13.5434454,
#                             'type': 'node'},
#                         {   'id': 259404815,
#                             'lat': 52.4350058,
#                             'lon': 13.5425053,
#                             'type': 'node'},
#                         {   'id': 23925123,
#                             'nodes': [259404815, 259404816],
#                             'tags': {   'highway': 'residential',
#                                         'maxspeed': '30',
#                                         'name': 'Abtstraße',
#                                         'oneway': 'yes',
#                                         'postal_code': '12489',
#                                         'smoothness': 'bad',
#                                         'surface': 'cobblestone'},
#                             'type': 'way'},
#                         {   'id': 383448928,
#                             'nodes': [484225813, 3867211100],
#                             'tags': {   'bench': 'yes',
#                                         'bin': 'yes',
#                                         'bus': 'yes',
#                                         'name': 'Abtstraße',
#                                         'public_transport': 'platform',
#                                         'shelter': 'yes',
#                                         'tactile_paving': 'no',
#                                         'wheelchair': 'yes'},
#                             'type': 'way'}]}]
# [   {   'elements': [   {   'id': 153726644,
#                             'lat': 52.4131496,
#                             'lon': 13.6758432,
#                             'type': 'node'},
#                         {   'id': 297395444,
#                             'lat': 52.4134819,
#                             'lon': 13.6751275,
#                             'type': 'node'},
#                         {   'id': 297456638,
#                             'lat': 52.4127865,
#                             'lon': 13.6766275,
#                             'type': 'node'},
#                         {   'id': 297456636,
#                             'lat': 52.4126538,
#                             'lon': 13.6768449,
#                             'type': 'node'},
#                         {   'id': 297395454,
#                             'lat': 52.4132969,
#                             'lon': 13.6755103,
#                             'type': 'node'},
#                         {   'id': 297456639,
#                             'lat': 52.4130182,
#                             'lon': 13.6761562,
#                             'type': 'node'},
#                         {   'id': 24580331,
#                             'nodes': [   297456636,
#                                          297456638,
#                                          297456639,
#                                          153726644,
#                                          297395454,
#                                          297395444],
#                             'tags': {   'highway': 'residential',
#                                         'maxspeed': '30',
#                                         'name': 'Abtweiler Straße',
#                                         'postal_code': '12559'},
#                             'type': 'way'}]}]
# [                              ] | ETA: 00:38:22 | Item ID: Achardstraße
# [   {   'elements': [   {   'id': 266624961,
#                             'lat': 52.4993591,
#                             'lon': 13.5829706,
#                             'type': 'node'},
#                         {   'id': 266624962,
#                             'lat': 52.4993632,
#                             'lon': 13.5836272,
#                             'type': 'node'},
#                         {   'id': 266626241,
#                             'lat': 52.4990142,
#                             'lon': 13.5861249,
#                             'type': 'node'},
#                         {   'id': 405040162,
#                             'lat': 52.500296,
#                             'lon': 13.5791492,
#                             'type': 'node'},
#                         {   'id': 266626117,
#                             'lat': 52.499528,
#                             'lon': 13.581863,
#                             'type': 'node'},
#                         {   'id': 59851237,
#                             'lat': 52.4991859,
#                             'lon': 13.58506,
#                             'type': 'node'},
#                         {   'id': 405040165,
#                             'lat': 52.4997659,
#                             'lon': 13.5791,
#                             'type': 'node'},
#                         {   'id': 2224984081,
#                             'lat': 52.4995297,
#                             'lon': 13.5818415,
#                             'type': 'node'},
#                         {   'id': 266627188,
#                             'lat': 52.4997032,
#                             'lon': 13.5807081,
#                             'type': 'node'},
#                         {   'id': 266625910,
#                             'lat': 52.499729,
#                             'lon': 13.5805894,
#                             'type': 'node'},
#                         {   'id': 3815947260,
#                             'lat': 52.4996487,
#                             'lon': 13.5790401,
#                             'type': 'node'},
#                         {   'id': 3815947261,
#                             'lat': 52.5004655,
#                             'lon': 13.5792531,
#                             'type': 'node'},
#                         {   'id': 266624959,
#                             'lat': 52.4999738,
#                             'lon': 13.5791123,
#                             'type': 'node'},
#                         {   'id': 7997682,
#                             'nodes': [   266624959,
#                                          266625910,
#                                          266627188,
#                                          2224984081,
#                                          266626117,
#                                          266624961,
#                                          266624962,
#                                          59851237,
#                                          266626241],
#                             'tags': {   'hazmat': {'water': 'no'},
#                                         'highway': 'residential',
#                                         'maxspeed': '30',
#                                         'name': 'Achardstraße',
#                                         'postal_code': '12621'},
#                             'type': 'way'},
#                         {   'id': 378178033,
#                             'nodes': [3815947261, 405040162],
#                             'tags': {   'bench': 'yes',
#                                         'bin': 'yes',
#                                         'bus': 'yes',
#                                         'name': 'Achardstraße',
#                                         'public_transport': 'platform',
#                                         'shelter': 'yes'},
#                             'type': 'way'},
#                         {   'id': 378178034,
#                             'nodes': [3815947260, 405040165],
#                             'tags': {   'bench': 'yes',
#                                         'bin': 'yes',
#                                         'bus': 'yes',
#                                         'name': 'Achardstraße',
#                                         'public_transport': 'platform',
#                                         'shelter': 'yes'},
#                             'type': 'way'}]}]
# [   {   'elements': [   {   'id': 34440768,
#                             'lat': 52.5423627,
#                             'lon': 13.2027324,
#                             'type': 'node'},
#                         {   'id': 34440769,
#                             'lat': 52.5424154,
#                             'lon': 13.2028229,
#                             'type': 'node'},
#                         {   'id': 34440770,
#                             'lat': 52.5425524,
#                             'lon': 13.2029708,
#                             'type': 'node'},
#                         {   'id': 34440871,
#                             'lat': 52.5424948,
#                             'lon': 13.202447,
#                             'type': 'node'},
#                         {   'id': 34440872,
#                             'lat': 52.5424126,
#                             'lon': 13.2025876,
#                             'type': 'node'},
#                         {   'id': 34440767,
#                             'lat': 52.5412016,
#                             'lon': 13.2030666,
#                             'type': 'node'},
#                         {   'id': 5075792,
#                             'nodes': [34440767, 34440768, 34440769, 34440770],
#                             'tags': {   'highway': 'residential',
#                                         'name': 'Achenbachstraße',
#                                         'postal_code': '13585'},
#                             'type': 'way'},
#                         {   'id': 5075793,
#                             'nodes': [34440871, 34440872, 34440768],
#                             'tags': {   'highway': 'residential',
#                                         'name': 'Achenbachstraße',
#                                         'postal_code': '13585'},
#                             'type': 'way'}]}]
# [   {   'elements': [   {   'id': 2282907142,
#                             'lat': 52.4126699,
#                             'lon': 13.3341574,
#                             'type': 'node'},
#                         {   'id': 301165321,
#                             'lat': 52.4137348,
#                             'lon': 13.3340016,
#                             'type': 'node'},
#                         {   'id': 3738323083,
#                             'lat': 52.4155898,
#                             'lon': 13.3342048,
#                             'type': 'node'},
#                         {   'id': 3738323736,
#                             'lat': 52.4158374,
#                             'lon': 13.3342591,
#                             'type': 'node'},
#                         {   'id': 3738323998,
#                             'lat': 52.4160047,
#                             'lon': 13.3343091,
#                             'type': 'node'},
#                         {   'id': 3738321445,
#                             'lat': 52.4148001,
#                             'lon': 13.3340519,
#                             'type': 'node'},
#                         {   'id': 3738322216,
#                             'lat': 52.4151784,
#                             'lon': 13.334109,
#                             'type': 'node'},
#                         {   'id': 1611914029,
#                             'lat': 52.415392,
#                             'lon': 13.3341519,
#                             'type': 'node'},
#                         {   'id': 2252500022,
#                             'lat': 52.4149762,
#                             'lon': 13.3340847,
#                             'type': 'node'},
#                         {   'id': 1611898039,
#                             'lat': 52.4131556,
#                             'lon': 13.3340646,
#                             'type': 'node'},
#                         {   'id': 3738314682,
#                             'lat': 52.4111609,
#                             'lon': 13.3345275,
#                             'type': 'node'},
#                         {   'id': 1611914170,
#                             'lat': 52.4172486,
#                             'lon': 13.3348136,
#                             'type': 'node'},
#                         {   'id': 1611898049,
#                             'lat': 52.413802,
#                             'lon': 13.3339966,
#                             'type': 'node'},
#                         {   'id': 3738325319,
#                             'lat': 52.4166681,
#                             'lon': 13.3345478,
#                             'type': 'node'},
#                         {   'id': 257094216,
#                             'lat': 52.4103713,
#                             'lon': 13.3347356,
#                             'type': 'node'},
#                         {   'id': 257094217,
#                             'lat': 52.410063,
#                             'lon': 13.3348098,
#                             'type': 'node'},
#                         {   'id': 257094218,
#                             'lat': 52.4100017,
#                             'lon': 13.3345495,
#                             'type': 'node'},
# ...
#                             'lat': 52.5672648,
#                             'lon': 13.4368355,
#                             'type': 'node'},
#                         {   'id': 2430325945,
#                             'lat': 52.5673268,
#                             'lon': 13.4368618,
#                             'type': 'node'},
#                         {   'id': 2430325946,
#                             'lat': 52.5673773,
#                             'lon': 13.436856,
#                             'type': 'node'},
#                         {   'id': 2430325947,
#                             'lat': 52.5674279,
#                             'lon': 13.4368006,
#                             'type': 'node'},
#                         {   'id': 142722143,
#                             'nodes': [   1561904050,
#                                          2430325335,
#                                          2430325942,
#                                          29778582],
#                             'tags': {   'highway': 'residential',
#                                         'maxspeed': '30',
#                                         'name': 'Aidastraße',
#                                         'postal_code': '13089'},
#                             'type': 'way'},
#                         {   'id': 234909353,
#                             'nodes': [   2430325335,
#                                          2430325947,
#                                          2430325946,
#                                          2430325945,
#                                          2430325944,
#                                          2430325943,
#                                          2721129360,
#                                          2430325942],
#                             'tags': {   'highway': 'service',
#                                         'maxspeed': '30',
#                                         'name': 'Aidastraße'},
#                             'type': 'way'}]}]
# [   {   'elements': [   {   'id': 4004265232,
#                             'lat': 52.4781396,
#                             'lon': 13.6098942,
#                             'type': 'node'},
#                         {   'id': 30561426,
#                             'lat': 52.5895693,
#                             'lon': 13.3953172,
#                             'type': 'node'},
#                         {   'id': 4004265240,
#                             'lat': 52.4777553,
#                             'lon': 13.6135415,
#                             'type': 'node'},
#                         {   'id': 4004265247,
#                             'lat': 52.4789301,
#                             'lon': 13.6035114,
#                             'type': 'node'},
#                         {   'id': 459663520,
#                             'lat': 52.5180637,
#                             'lon': 13.275674,
#                             'type': 'node'},
#                         {   'id': 27559587,
#                             'lat': 52.5196594,
#                             'lon': 13.2668769,
#                             'type': 'node'},
#                         {   'id': 27559588,
#                             'lat': 52.5192222,
#                             'lon': 13.2693261,
#                             'type': 'node'},
#                         {   'id': 4004265268,
#                             'lat': 52.4786659,
#                             'lon': 13.6056859,
#                             'type': 'node'},
#                         {   'id': 27559476,
#                             'lat': 52.5186827,
#                             'lon': 13.2723086,
#                             'type': 'node'},
#                         {   'id': 28997947,
#                             'lat': 52.5203761,
#                             'lon': 13.2627392,
#                             'type': 'node'},
#                         {   'id': 242925769,
#                             'lat': 52.4792448,
#                             'lon': 13.6009407,
#                             'type': 'node'},
#                         {   'id': 242925778,
#                             'lat': 52.478649,
#                             'lon': 13.6058262,
#                             'type': 'node'},
#                         {   'id': 27559381,
#                             'lat': 52.5177097,
#                             'lon': 13.2777326,
#                             'type': 'node'},
#                         {   'id': 242925785,
#                             'lat': 52.4783798,
#                             'lon': 13.6079921,
#                             'type': 'node'},
#                         {   'id': 353849050,
#                             'lat': 52.477707,
#                             'lon': 13.6140217,
#                             'type': 'node'},
#                         {   'id': 353849052,
#                             'lat': 52.4781164,
#                             'lon': 13.6100986,
#                             'type': 'node'},
#                         {   'id': 30561503,
#                             'lat': 52.5899664,
#                             'lon': 13.3951426,
#                             'type': 'node'},
#                         {   'id': 353849056,
#                             'lat': 52.4788719,
#                             'lon': 13.6039857,
#                             'type': 'node'},
#                         {   'id': 27559392,
#                             'lat': 52.5181029,
#                             'lon': 13.2754024,
#                             'type': 'node'},
#                         {   'id': 242925797,
#                             'lat': 52.4789077,
#                             'lon': 13.6036942,
#                             'type': 'node'},
#                         {   'id': 2904416230,
#                             'lat': 52.5201534,
#                             'lon': 13.2640248,
#                             'type': 'node'},
#                         {   'id': 286022127,
#                             'lat': 52.4787998,
#                             'lon': 13.6045754,
#                             'type': 'node'},
#                         {   'id': 242925808,
#                             'lat': 52.4781663,
#                             'lon': 13.6096577,
#                             'type': 'node'},
#                         {   'id': 242925812,
#                             'lat': 52.4779804,
#                             'lon': 13.6114227,
#                             'type': 'node'},
#                         {   'id': 324150646,
#                             'lat': 52.4776969,
#                             'lon': 13.6141201,
#                             'type': 'node'},
#                         {   'id': 30561400,
#                             'lat': 52.5916886,
#                             'lon': 13.3943001,
#                             'type': 'node'},
#                         {   'id': 242925820,
#                             'lat': 52.4777873,
#                             'lon': 13.6132127,
#                             'type': 'node'},
#                         {   'id': 4777292,
#                             'nodes': [30561426, 30561503],
#                             'tags': {   'highway': 'residential',
#                                         'name': 'Akazienallee',
#                                         'postal_code': '13156'},
#                             'type': 'way'},
#                         {   'id': 4777305,
#                             'nodes': [30561503, 30561400],
#                             'tags': {   'highway': 'residential',
#                                         'maxspeed': '30',
#                                         'name': 'Akazienallee',
#                                         'postal_code': '13158',
#                                         'surface': 'unpaved'},
#                             'type': 'way'},
#                         {   'id': 22650453,
#                             'nodes': [   242925769,
#                                          4004265247,
#                                          242925797,
#                                          353849056,
#                                          286022127,
#                                          4004265268,
#                                          242925778,
#                                          242925785,
#                                          242925808,
#                                          4004265232,
#                                          353849052,
#                                          242925812,
#                                          242925820,
#                                          4004265240,
#                                          353849050,
#                                          324150646],
#                             'tags': {   'highway': 'tertiary',
#                                         'lanes': '2',
#                                         'maxspeed': '50',
#                                         'name': 'Akazienallee',
#                                         'postal_code': '12623',
#                                         'sidewalk': 'both',
#                                         'surface': 'asphalt'},
#                             'type': 'way'},
#                         {   'id': 38763327,
#                             'nodes': [   28997947,
#                                          2904416230,
#                                          27559587,
#                                          27559588,
#                                          27559476,
#                                          27559392,
#                                          459663520,
#                                          27559381],
#                             'tags': {   'highway': 'residential',
#                                         'lit': 'yes',
#                                         'maxspeed': '30',
#                                         'name': 'Akazienallee',
#                                         'postal_code': '14050'},
#                             'type': 'way'}]}]
# [   {   'elements': [   {   'id': 1609189130,
#                             'lat': 52.4106774,
#                             'lon': 13.5675107,
#                             'type': 'node'},
#                         {   'id': 1609189154,
#                             'lat': 52.4115986,
#                             'lon': 13.5684572,
#                             'type': 'node'},
#                         {   'id': 147717001,
#                             'nodes': [1609189130, 1609189154],
#                             'tags': {   'highway': 'residential',
#                                         'lit': 'yes',
#                                         'maxspeed': '30',
#                                         'name': 'Akazienhof',
#                                         'note': '"Acacia Court"',
#                                         'postal_code': '12524',
#                                         'smoothness': 'intermediate',
#                                         'source': {'maxspeed': 'DE:zone30'},
#                                         'surface': 'asphalt'},
#                             'type': 'way'}]}]
# [   {   'elements': [   {   'id': 312291650,
#                             'lat': 52.4274466,
#                             'lon': 13.323304,
#                             'type': 'node'},
#                         {   'id': 312291652,
#                             'lat': 52.4267732,
#                             'lon': 13.3237695,
#                             'type': 'node'},
#                         {   'id': 3997900260,
#                             'lat': 52.4860128,
#                             'lon': 13.356043,
#                             'type': 'node'},
#                         {   'id': 27786597,
#                             'lat': 52.4897929,
#                             'lon': 13.3532136,
#                             'type': 'node'},
#                         {   'id': 27785385,
#                             'lat': 52.4860656,
#                             'lon': 13.3559857,
#                             'type': 'node'},
#                         {   'id': 27785387,
#                             'lat': 52.4859713,
#                             'lon': 13.3560936,
#                             'type': 'node'},
#                         {   'id': 27786217,
#                             'lat': 52.489218,
#                             'lon': 13.3533862,
#                             'type': 'node'},
#                         {   'id': 1657188874,
#                             'lat': 52.4867128,
#                             'lon': 13.3553344,
#                             'type': 'node'},
#                         {   'id': 27785390,
#                             'lat': 52.4874871,
#                             'lon': 13.354688,
#                             'type': 'node'},
#                         {   'id': 27786288,
#                             'lat': 52.488676,
#                             'lon': 13.3536878,
#                             'type': 'node'},
#                         {   'id': 3844383250,
#                             'lat': 52.4888081,
#                             'lon': 13.3535755,
#                             'type': 'node'},
#                         {   'id': 1657188891,
#                             'lat': 52.4889635,
#                             'lon': 13.3534528,
#                             'type': 'node'},
#                         {   'id': 253752635,
#                             'lat': 52.4655568,
#                             'lon': 13.6899311,
#                             'type': 'node'},
#                         {   'id': 301201115,
#                             'lat': 52.4895439,
#                             'lon': 13.3532877,
#                             'type': 'node'},
#                         {   'id': 23429865,
#                             'nodes': [   253752635,
#                                          253752628,
#                                          3025007959,
#                                          251541257],
#                             'tags': {   'highway': 'residential',
#                                         'maxspeed': '30',
#                                         'name': 'Akazienstraße',
#                                         'surface': 'cobblestone'},
#                             'type': 'way'},
#                         {   'id': 28425073,
#                             'nodes': [312291650, 312291652],
#                             'tags': {   'highway': 'residential',
#                                         'lit': 'yes',
#                                         'name': 'Akazienstraße',
#                                         'postal_code': '12207'},
#                             'type': 'way'},
#                         {   'id': 34625336,
#                             'nodes': [27785385, 3997900260, 27785387],
#                             'tags': {   'highway': 'residential',
#                                         'maxspeed': '50',
#                                         'name': 'Akazienstraße',
#                                         'oneway': 'yes',
#                                         'postal_code': '10823'},
#                             'type': 'way'},
#                         {   'id': 152953709,
#                             'nodes': [   27786597,
#                                          301201115,
#                                          27786217,
#                                          1657188891,
#                                          3844383250,
#                                          27786288,
#                                          27785390,
#                                          1657188874,
#                                          27785385],
#                             'tags': {   'highway': 'residential',
#                                         'lanes': '2',
#                                         'maxspeed': '30',
#                                         'name': 'Akazienstraße',
#                                         'postal_code': '10823',
#                                         'sidewalk': 'both'},
#                             'type': 'way'}]}]
# Akazienstraße could not be inserted.
# [                              ] | ETA: 00:40:06 | Item ID: Akazienweg

# %%
bla = assembleStreet(ways, "Achenseeweg")
# Out:
# 1611889028
# 257094218
# 257094217
# 257094216
# 3738314682.0
# 1611897969
# 1611897981
# 2282907142.0
# 1611898039
# 3738319334.0
# 301165321
# 1611898049
# 301165298
# 3738321101.0
# 3738321445.0
# 2252500022.0
# 3738322216.0
# 1611914029
# 3738323083.0
# 3738323736.0
# 3738323998.0
# 3738324469.0
# 1611914111
# 3738325319.0
# 1611914170
# [   {   'elements': [   {   'id': 2282907142,
#                             'lat': 52.4126699,
#                             'lon': 13.3341574,
#                             'type': 'node'},
#                         {   'id': 301165321,
#                             'lat': 52.4137348,
#                             'lon': 13.3340016,
#                             'type': 'node'},
#                         {   'id': 3738323083,
#                             'lat': 52.4155898,
#                             'lon': 13.3342048,
#                             'type': 'node'},
#                         {   'id': 3738323736,
#                             'lat': 52.4158374,
#                             'lon': 13.3342591,
#                             'type': 'node'},
#                         {   'id': 3738323998,
#                             'lat': 52.4160047,
#                             'lon': 13.3343091,
#                             'type': 'node'},
#                         {   'id': 3738321445,
#                             'lat': 52.4148001,
#                             'lon': 13.3340519,
#                             'type': 'node'},
#                         {   'id': 3738322216,
#                             'lat': 52.4151784,
#                             'lon': 13.334109,
#                             'type': 'node'},
#                         {   'id': 1611914029,
#                             'lat': 52.415392,
#                             'lon': 13.3341519,
#                             'type': 'node'},
#                         {   'id': 2252500022,
#                             'lat': 52.4149762,
#                             'lon': 13.3340847,
#                             'type': 'node'},
#                         {   'id': 1611898039,
#                             'lat': 52.4131556,
#                             'lon': 13.3340646,
#                             'type': 'node'},
#                         {   'id': 3738314682,
#                             'lat': 52.4111609,
#                             'lon': 13.3345275,
#                             'type': 'node'},
#                         {   'id': 1611914170,
#                             'lat': 52.4172486,
#                             'lon': 13.3348136,
#                             'type': 'node'},
#                         {   'id': 1611898049,
#                             'lat': 52.413802,
#                             'lon': 13.3339966,
#                             'type': 'node'},
#                         {   'id': 3738325319,
#                             'lat': 52.4166681,
#                             'lon': 13.3345478,
#                             'type': 'node'},
#                         {   'id': 257094216,
#                             'lat': 52.4103713,
#                             'lon': 13.3347356,
#                             'type': 'node'},
#                         {   'id': 257094217,
#                             'lat': 52.410063,
#                             'lon': 13.3348098,
#                             'type': 'node'},
#                         {   'id': 257094218,
#                             'lat': 52.4100017,
#                             'lon': 13.3345495,
#                             'type': 'node'},
#                         {   'id': 3738321101,
#                             'lat': 52.4146057,
#                             'lon': 13.3340333,
#                             'type': 'node'},
#                         {   'id': 3738319334,
#                             'lat': 52.4133926,
#                             'lon': 13.3340314,
#                             'type': 'node'},
#                         {   'id': 1611897969,
#                             'lat': 52.4112233,
#                             'lon': 13.3345255,
#                             'type': 'node'},
#                         {   'id': 301165298,
#                             'lat': 52.4140065,
#                             'lon': 13.3340007,
#                             'type': 'node'},
#                         {   'id': 3738324469,
#                             'lat': 52.4162462,
#                             'lon': 13.3343891,
#                             'type': 'node'},
#                         {   'id': 1611897981,
#                             'lat': 52.4121357,
#                             'lon': 13.3342988,
#                             'type': 'node'},
#                         {   'id': 1611914111,
#                             'lat': 52.4164563,
#                             'lon': 13.3344592,
#                             'type': 'node'},
#                         {   'id': 148077401,
#                             'nodes': [   1611889028,
#                                          257094218,
#                                          257094217,
#                                          257094216,
#                                          3738314682,
#                                          1611897969,
#                                          1611897981,
#                                          2282907142,
#                                          1611898039,
#                                          3738319334,
#                                          301165321,
#                                          1611898049,
#                                          301165298,
#                                          3738321101,
#                                          3738321445,
#                                          2252500022,
#                                          3738322216,
#                                          1611914029,
#                                          3738323083,
#                                          3738323736,
#                                          3738323998,
#                                          3738324469,
#                                          1611914111,
#                                          3738325319,
#                                          1611914170],
#                             'tags': {   'highway': 'residential',
#                                         'lit': 'yes',
#                                         'maxspeed': '30',
#                                         'name': 'Achenseeweg',
#                                         'postal_code': '12209'},
#                             'type': 'way'}]}]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-e210adb1254e> in <module>()
# ----> 1 bla = assembleStreet(ways, "Achenseeweg")
#
# <ipython-input-41-60a795a52ad4> in assembleStreet(ways, streetname, drawit)
#      24     oxelements = [{"elements": elemnodes + elemways}]
#      25     pp.pprint(oxelements)
# ---> 26     G = ox.create_graph(oxelements, retain_all=True)
#      27     if drawit:
#      28         fig, ax = ox.plot_graph(G)
#
# /Users/szellmi/anaconda3/lib/python3.5/site-packages/osmnx/osmnx.py in create_graph(response_jsons, name, retain_all, network_type)
#    1501
#    1502     # add length (great circle distance between nodes) attribute to each edge to use as weight
# -> 1503     G = add_edge_lengths(G)
#    1504
#    1505     return G
#
# /Users/szellmi/anaconda3/lib/python3.5/site-packages/osmnx/osmnx.py in add_edge_lengths(G)
#    1341
#    1342         #geopy points are (lat, lon) so that's (y, x) for this great_circle calculation
# -> 1343         u_point = (G.node[u]['y'], G.node[u]['x'])
#    1344         v_point = (G.node[v]['y'], G.node[v]['x'])
#    1345         edge_length = great_circle(u_point, v_point).m
#
# KeyError: 'y'

# %%
# Tests
bla = ox.osm_net_download(north=48.80393, south=48.80201, east=9.22657, west=9.22126)
pp.pprint(bla)
